# %% [markdown]
# ## Imports

# %%
import warnings
warnings.filterwarnings('ignore')

import os, gc, random, time

import pandas as pd
import numpy as np

from tqdm.notebook import tqdm
from sklearn.model_selection import TimeSeriesSplit

from scipy.special import expit

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from catalyst import dl
from catalyst.callbacks.metrics import AUCCallback
from catalyst.contrib.nn.schedulers import ReduceLROnPlateau
from catalyst.utils.misc import set_global_seed
from catalyst.utils.tracing import load_traced_model

# %% [markdown]
# ## Init params

# %%
seed        = 42
device      = 'cuda:0'
num_epochs  = 20
lr          = 0.005
lr_patience = 5
lr_factor   = 0.4
es_patience = 11
logdir      = './logdir/'
batch_size  = 8192

set_global_seed(seed)

# %% [markdown]
# ## Prepare data

# %%
data = pd.read_csv('data/train.csv')
data = data.sort_values('ts_id')

data = data.query('weight > 0')
data = data.reset_index(drop=True)

fillna = data.min() - 1
data   = data.fillna(fillna)

data['target'] = expit(data['resp']*500)

test = data.iloc[-len(data)//20:].reset_index(drop=True)
data = data.iloc[:-len(data)//20].reset_index(drop=True)

# %%
features = [f'feature_{i}' for i in range(130)]

# %% [markdown]
# ## Dataset

# %%
class MarketDataset:
    def __init__(self, df, features, target=None):
        self.features = df[features].values
        self.target = target
        
        if self.target is not None:
            self.target = df[self.target].values

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        data = dict(
            features = torch.FloatTensor(self.features[idx])
        )
        if self.target is not None:
            data['targets'] = torch.FloatTensor([self.target[idx]])
            data['labels'] = torch.FloatTensor([self.target[idx] > 0.5])
            
        return data

# %% [markdown]
# ## Loaders

# %%
def get_loaders(dataframes, batch_size=batch_size):
    datasets = {
        key: MarketDataset(df, features, target='target')
        for key, df in dataframes.items()
    }
    loaders = dict()
    for key, value in datasets.items():
        shuffle = False
        if 'train' == key:
            shuffle = True
            
        loaders[key] = DataLoader(value, batch_size=batch_size, shuffle=shuffle)
    
    return loaders

# %% [markdown]
# ## Model

# %%
class ResLinear(nn.Module):
    def __init__(
        self,
        in_features,
        out_features,
        p = 0.3,
    ):
        super().__init__()
        self.linear1 = nn.Sequential(
            nn.BatchNorm1d(in_features),
            nn.Dropout(p),
            nn.Linear(in_features, in_features),
            nn.LeakyReLU(),
        )
        self.linear2 = nn.Sequential(
            nn.BatchNorm1d(in_features),
            nn.Dropout(p),
            nn.Linear(in_features, out_features),
            nn.LeakyReLU(),
        )
    
    def forward(self, x):
        return self.linear2(x + self.linear1(x))


class SubModel(nn.Module):
    def __init__(
        self,
        features_size,
        hidden_size  = 64,
        dropout_rate = 0.3,
        n_layers     = 4,
    ):
        super().__init__()
        layers = []
        
        now_features = features_size
        new_features = hidden_size
        
        for _ in range(n_layers):
            layers.append(ResLinear(now_features, new_features))
            
            now_features = new_features
            new_features = max(8, new_features // 2)
        
        layers.append(nn.Linear(now_features, 1))
            
        self.layers = nn.Sequential(*layers)


    def forward(self, x):
        return self.layers(x)
    
    
class Model(nn.Module):
    def __init__(
        self,
        params,
    ):
        super().__init__()
        submodels = []
        for p in params:
            submodels.append(SubModel(**p))
        
        self.submodels = nn.ModuleList(submodels)
        self.linear    = nn.Linear(len(params), 1)
        
    def forward(self, x):
        result = {
            f'logits_{i}': submodel(x)
            for i, submodel in enumerate(self.submodels)
        }
        x = torch.cat([v for v in result.values()], dim=1)
        result['logits'] = self.linear(x)
        return result

class ModelTraced(Model):
    def forward(self, x):
        result = [submodel(x) for submodel in self.submodels]
        x = torch.cat(result, dim=1)
        return self.linear(x)

# %% [markdown]
# ## Train

# %%
def get_callbacks(params):
    metrics = {
        f'loss_{i}':1/(2*len(params))
        for i in range(len(params))
    }
    metrics.update({'loss_last':1/2})
    
    callbacks = [
        dl.EarlyStoppingCallback(
            patience = es_patience,
            metric   = 'auc',
            minimize = False,
        ),
        AUCCallback(input_key='labels'),
    ]

    callbacks.extend([
        dl.CriterionCallback(
            input_key     = 'targets',
            output_key    = f'logits_{i}',
            criterion_key = 'bce',
            prefix        = f'loss_{i}',
        )
        for i in range(len(params))
    ])

    callbacks.extend([
        dl.CriterionCallback(
            input_key     = 'targets',
            output_key    = 'logits',
            criterion_key = 'bce',
            prefix        = 'loss_last',
        ),
        dl.MetricAggregationCallback(
            prefix  = "loss",
            metrics = metrics,
            mode    = 'weighted_sum',
        ),
    ])
    return callbacks

def get_cosc(model, params):
    criterion = dict(
        bce = torch.nn.BCEWithLogitsLoss(),
    )

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = ReduceLROnPlateau(
        optimizer = optimizer,
        mode      = 'max',
        patience  = lr_patience,
        factor    = lr_factor,
    )
    
    callbacks = get_callbacks(params)
    return criterion, optimizer, scheduler, callbacks

def train_model(params, dataframes, postfix_logdir):
    model        = Model(params)
    loaders      = get_loaders(dataframes)
    
    criterion, optimizer, scheduler, callbacks = get_cosc(model, params)
    
    runner = dl.SupervisedRunner(device='cuda:0', output_key=None)
    try:
        runner.train(
            model            = model,
            criterion        = criterion,
            optimizer        = optimizer,
            scheduler        = scheduler,
            loaders          = loaders,
            logdir           = logdir + postfix_logdir,
            num_epochs       = num_epochs,
            callbacks        = callbacks,
            main_metric      = 'auc',
            minimize_metric  = False,
            load_best_on_end = True,
            verbose          = False,
        )
    except KeyboardInterrupt:
        pass
    
    return model

# %% [markdown]
# ## Score

# %%
def utility_score_bincount(date, weight, resp, action):
    count_i = len(np.unique(date))
    Pi = np.bincount(date, weight * resp * action)
    t = np.sum(Pi) / np.sqrt(np.sum(Pi ** 2)) * np.sqrt(250 / count_i)
    u = np.clip(t, 0, 6) * np.sum(Pi)
    return u

def scoring(dataframe, pred):
    date   = dataframe['date'].values
    weight = dataframe['weight'].values
    resp   = dataframe['resp'].values
    
    return utility_score_bincount(
            date,
            weight,
            resp,
            np.where(pred >= 0.5, 1, 0).astype(int)
        )

def score(model, dataframe):
    loader = get_loaders({'valid':dataframe})['valid']
    
    runner = dl.SupervisedRunner(device='cuda:0', output_key=None)
    predict = runner.predict_loader(
        model  = model,
        loader = loader,
    )
    
    pred = torch.cat([p['logits'].sigmoid().cpu() for p in predict])
    pred = pred.numpy().squeeze()
    
    return scoring(dataframe, pred)

# %% [markdown]
# ## Train Models

# %%
# !rm -rf {logdir}

# %%
params =  [
    {'features_size': 130, 'n_layers': 3},
    {'features_size': 130, 'n_layers': 4},
    {'features_size': 130, 'n_layers': 5},
]

# %%
models = []
scores = []

N_SPLITS = 6

tscv = TimeSeriesSplit(n_splits=N_SPLITS)
for i, (train_index, valid_index) in tqdm(enumerate(tscv.split(data.index)), total=N_SPLITS):
    
    dataframes = dict(
        train = data.loc[train_index],
        valid = data.loc[valid_index],
    )
    fold_model  = train_model(params, dataframes, f'fold_{i}')
    valid_score = score(fold_model, data.loc[valid_index])
    test_score  = score(fold_model, test)
    
    models.append(fold_model)
    scores.append((valid_score, test_score))
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# [2021-02-22 18:29:44,049]
# 1/20 * Epoch 1 (_base): lr=0.0050 | momentum=0.9000
# 1/20 * Epoch 1 (train): auc=0.5033 | loss=0.6965 | loss_0=0.6937 | loss_1=0.6955 | loss_2=0.7075 | loss_last=0.6941
# 1/20 * Epoch 1 (valid): auc=0.5066 | loss=0.6939 | loss_0=0.6934 | loss_1=0.6955 | loss_2=0.6940 | loss_last=0.6936
# [2021-02-22 18:30:02,220]
# 2/20 * Epoch 2 (_base): lr=0.0050 | momentum=0.9000
# 2/20 * Epoch 2 (train): auc=0.5138 | loss=0.6929 | loss_0=0.6925 | loss_1=0.6939 | loss_2=0.6935 | loss_last=0.6926
# 2/20 * Epoch 2 (valid): auc=0.5150 | loss=0.6931 | loss_0=0.6929 | loss_1=0.6938 | loss_2=0.6935 | loss_last=0.6928
# [2021-02-22 18:30:20,030]
# 3/20 * Epoch 3 (_base): lr=0.0050 | momentum=0.9000
# 3/20 * Epoch 3 (train): auc=0.5307 | loss=0.6919 | loss_0=0.6917 | loss_1=0.6934 | loss_2=0.6917 | loss_last=0.6915
# 3/20 * Epoch 3 (valid): auc=0.5199 | loss=0.6931 | loss_0=0.6926 | loss_1=0.6933 | loss_2=0.6944 | loss_last=0.6927
# [2021-02-22 18:30:37,845]
# 4/20 * Epoch 4 (_base): lr=0.0050 | momentum=0.9000
# 4/20 * Epoch 4 (train): auc=0.5379 | loss=0.6911 | loss_0=0.6902 | loss_1=0.6932 | loss_2=0.6911 | loss_last=0.6907
# 4/20 * Epoch 4 (valid): auc=0.5206 | loss=0.6930 | loss_0=0.6926 | loss_1=0.6934 | loss_2=0.6942 | loss_last=0.6926
# [2021-02-22 18:30:55,529]
# 5/20 * Epoch 5 (_base): lr=0.0050 | momentum=0.9000
# 5/20 * Epoch 5 (train): auc=0.5511 | loss=0.6896 | loss_0=0.6884 | loss_1=0.6929 | loss_2=0.6896 | loss_last=0.6889
# 5/20 * Epoch 5 (valid): auc=0.5201 | loss=0.6942 | loss_0=0.6977 | loss_1=0.6930 | loss_2=0.6937 | loss_last=0.6935
# [2021-02-22 18:31:13,165]
# 6/20 * Epoch 6 (_base): lr=0.0050 | momentum=0.9000
# 6/20 * Epoch 6 (train): auc=0.5607 | loss=0.6878 | loss_0=0.6872 | loss_1=0.6924 | loss_2=0.6887 | loss_last=0.6863
# 6/20 * Epoch 6 (valid): auc=0.5167 | loss=0.6961 | loss_0=0.7020 | loss_1=0.6925 | loss_2=0.6934 | loss_last=0.6963
# [2021-02-22 18:31:31,007]
# 7/20 * Epoch 7 (_base): lr=0.0050 | momentum=0.9000
# 7/20 * Epoch 7 (train): auc=0.5658 | loss=0.6863 | loss_0=0.6854 | loss_1=0.6914 | loss_2=0.6880 | loss_last=0.6844
# 7/20 * Epoch 7 (valid): auc=0.5140 | loss=0.6968 | loss_0=0.7012 | loss_1=0.6923 | loss_2=0.6937 | loss_last=0.6979
# [2021-02-22 18:31:48,733]
# 8/20 * Epoch 8 (_base): lr=0.0050 | momentum=0.9000
# 8/20 * Epoch 8 (train): auc=0.5720 | loss=0.6849 | loss_0=0.6835 | loss_1=0.6907 | loss_2=0.6874 | loss_last=0.6825
# 8/20 * Epoch 8 (valid): auc=0.5151 | loss=0.6971 | loss_0=0.7004 | loss_1=0.6923 | loss_2=0.6942 | loss_last=0.6986
# [2021-02-22 18:32:06,412]
# 9/20 * Epoch 9 (_base): lr=0.0050 | momentum=0.9000
# 9/20 * Epoch 9 (train): auc=0.5756 | loss=0.6841 | loss_0=0.6826 | loss_1=0.6905 | loss_2=0.6871 | loss_last=0.6815
# 9/20 * Epoch 9 (valid): auc=0.5129 | loss=0.6987 | loss_0=0.7025 | loss_1=0.6926 | loss_2=0.6941 | loss_last=0.7009
# [2021-02-22 18:32:24,288]
# 10/20 * Epoch 10 (_base): lr=0.0020 | momentum=0.9000
# 10/20 * Epoch 10 (train): auc=0.5790 | loss=0.6831 | loss_0=0.6814 | loss_1=0.6900 | loss_2=0.6863 | loss_last=0.6802
# 10/20 * Epoch 10 (valid): auc=0.5139 | loss=0.6992 | loss_0=0.7026 | loss_1=0.6925 | loss_2=0.6945 | loss_last=0.7018
# [2021-02-22 18:32:42,133]
# 11/20 * Epoch 11 (_base): lr=0.0020 | momentum=0.9000
# 11/20 * Epoch 11 (train): auc=0.5824 | loss=0.6821 | loss_0=0.6803 | loss_1=0.6894 | loss_2=0.6858 | loss_last=0.6790
# 11/20 * Epoch 11 (valid): auc=0.5126 | loss=0.6998 | loss_0=0.7034 | loss_1=0.6926 | loss_2=0.6946 | loss_last=0.7027
# [2021-02-22 18:33:00,066]
# 12/20 * Epoch 12 (_base): lr=0.0020 | momentum=0.9000
# 12/20 * Epoch 12 (train): auc=0.5858 | loss=0.6814 | loss_0=0.6795 | loss_1=0.6891 | loss_2=0.6852 | loss_last=0.6782
# 12/20 * Epoch 12 (valid): auc=0.5123 | loss=0.7008 | loss_0=0.7042 | loss_1=0.6927 | loss_2=0.6952 | loss_last=0.7041
# [2021-02-22 18:33:17,844]
# 13/20 * Epoch 13 (_base): lr=0.0020 | momentum=0.9000
# 13/20 * Epoch 13 (train): auc=0.5858 | loss=0.6811 | loss_0=0.6792 | loss_1=0.6887 | loss_2=0.6849 | loss_last=0.6778
# 13/20 * Epoch 13 (valid): auc=0.5120 | loss=0.7010 | loss_0=0.7046 | loss_1=0.6932 | loss_2=0.6952 | loss_last=0.7044
# [2021-02-22 18:33:35,759]
# 14/20 * Epoch 14 (_base): lr=0.0020 | momentum=0.9000
# 14/20 * Epoch 14 (train): auc=0.5858 | loss=0.6807 | loss_0=0.6788 | loss_1=0.6881 | loss_2=0.6848 | loss_last=0.6774
# 14/20 * Epoch 14 (valid): auc=0.5121 | loss=0.7034 | loss_0=0.7079 | loss_1=0.6933 | loss_2=0.6957 | loss_last=0.7079
# [2021-02-22 18:33:53,415]
# 15/20 * Epoch 15 (_base): lr=0.0020 | momentum=0.9000
# 15/20 * Epoch 15 (train): auc=0.5891 | loss=0.6801 | loss_0=0.6784 | loss_1=0.6873 | loss_2=0.6842 | loss_last=0.6769
# 15/20 * Epoch 15 (valid): auc=0.5109 | loss=0.7012 | loss_0=0.7044 | loss_1=0.6939 | loss_2=0.6954 | loss_last=0.7045
# Early stop at 15 epoch
# Top best models:
# logdir/fold_0/checkpoints/train.4.pth	0.5206
# => Loading checkpoint logdir/fold_0/checkpoints/best_full.pth
# loaded state checkpoint logdir/fold_0/checkpoints/best_full.pth (global epoch 4, epoch 4, stage train)
# [2021-02-22 18:34:32,661]
# 1/20 * Epoch 1 (_base): lr=0.0050 | momentum=0.9000
# 1/20 * Epoch 1 (train): auc=0.5222 | loss=0.6942 | loss_0=0.6930 | loss_1=0.6932 | loss_2=0.7020 | loss_last=0.6924
# 1/20 * Epoch 1 (valid): auc=0.5277 | loss=0.6919 | loss_0=0.6917 | loss_1=0.6922 | loss_2=0.6927 | loss_last=0.6917
# [2021-02-22 18:35:00,348]
# 2/20 * Epoch 2 (_base): lr=0.0050 | momentum=0.9000
# 2/20 * Epoch 2 (train): auc=0.5373 | loss=0.6912 | loss_0=0.6910 | loss_1=0.6917 | loss_2=0.6924 | loss_last=0.6907
# 2/20 * Epoch 2 (valid): auc=0.5303 | loss=0.6915 | loss_0=0.6913 | loss_1=0.6915 | loss_2=0.6922 | loss_last=0.6912
# [2021-02-22 18:35:28,125]
# 3/20 * Epoch 3 (_base): lr=0.0050 | momentum=0.9000
# 3/20 * Epoch 3 (train): auc=0.5424 | loss=0.6903 | loss_0=0.6901 | loss_1=0.6909 | loss_2=0.6917 | loss_last=0.6898
# 3/20 * Epoch 3 (valid): auc=0.5282 | loss=0.6915 | loss_0=0.6916 | loss_1=0.6913 | loss_2=0.6918 | loss_last=0.6914
# [2021-02-22 18:35:55,992]
# 4/20 * Epoch 4 (_base): lr=0.0050 | momentum=0.9000
# 4/20 * Epoch 4 (train): auc=0.5468 | loss=0.6895 | loss_0=0.6891 | loss_1=0.6903 | loss_2=0.6911 | loss_last=0.6888
# 4/20 * Epoch 4 (valid): auc=0.5278 | loss=0.6915 | loss_0=0.6920 | loss_1=0.6910 | loss_2=0.6915 | loss_last=0.6916
# [2021-02-22 18:36:23,739]
# 5/20 * Epoch 5 (_base): lr=0.0050 | momentum=0.9000
# 5/20 * Epoch 5 (train): auc=0.5497 | loss=0.6887 | loss_0=0.6884 | loss_1=0.6898 | loss_2=0.6905 | loss_last=0.6879
# 5/20 * Epoch 5 (valid): auc=0.5284 | loss=0.6913 | loss_0=0.6914 | loss_1=0.6914 | loss_2=0.6911 | loss_last=0.6913
# [2021-02-22 18:36:51,478]
# 6/20 * Epoch 6 (_base): lr=0.0050 | momentum=0.9000
# 6/20 * Epoch 6 (train): auc=0.5523 | loss=0.6881 | loss_0=0.6879 | loss_1=0.6892 | loss_2=0.6901 | loss_last=0.6871
# 6/20 * Epoch 6 (valid): auc=0.5285 | loss=0.6914 | loss_0=0.6916 | loss_1=0.6911 | loss_2=0.6910 | loss_last=0.6915
# [2021-02-22 18:37:19,202]
# 7/20 * Epoch 7 (_base): lr=0.0050 | momentum=0.9000
# 7/20 * Epoch 7 (train): auc=0.5559 | loss=0.6875 | loss_0=0.6874 | loss_1=0.6888 | loss_2=0.6898 | loss_last=0.6863
# 7/20 * Epoch 7 (valid): auc=0.5277 | loss=0.6915 | loss_0=0.6916 | loss_1=0.6914 | loss_2=0.6912 | loss_last=0.6915
# [2021-02-22 18:37:47,029]
# 8/20 * Epoch 8 (_base): lr=0.0020 | momentum=0.9000
# 8/20 * Epoch 8 (train): auc=0.5583 | loss=0.6868 | loss_0=0.6869 | loss_1=0.6884 | loss_2=0.6893 | loss_last=0.6854
# 8/20 * Epoch 8 (valid): auc=0.5258 | loss=0.6921 | loss_0=0.6927 | loss_1=0.6916 | loss_2=0.6915 | loss_last=0.6923
# [2021-02-22 18:38:14,743]
# 9/20 * Epoch 9 (_base): lr=0.0020 | momentum=0.9000
# 9/20 * Epoch 9 (train): auc=0.5618 | loss=0.6859 | loss_0=0.6860 | loss_1=0.6879 | loss_2=0.6886 | loss_last=0.6844
# 9/20 * Epoch 9 (valid): auc=0.5263 | loss=0.6920 | loss_0=0.6924 | loss_1=0.6914 | loss_2=0.6912 | loss_last=0.6923
# [2021-02-22 18:38:42,664]
# 10/20 * Epoch 10 (_base): lr=0.0020 | momentum=0.9000
# 10/20 * Epoch 10 (train): auc=0.5644 | loss=0.6853 | loss_0=0.6854 | loss_1=0.6874 | loss_2=0.6883 | loss_last=0.6835
# 10/20 * Epoch 10 (valid): auc=0.5261 | loss=0.6921 | loss_0=0.6926 | loss_1=0.6912 | loss_2=0.6915 | loss_last=0.6924
# [2021-02-22 18:39:10,597]
# 11/20 * Epoch 11 (_base): lr=0.0020 | momentum=0.9000
# 11/20 * Epoch 11 (train): auc=0.5659 | loss=0.6848 | loss_0=0.6851 | loss_1=0.6871 | loss_2=0.6879 | loss_last=0.6829
# 11/20 * Epoch 11 (valid): auc=0.5272 | loss=0.6921 | loss_0=0.6925 | loss_1=0.6916 | loss_2=0.6911 | loss_last=0.6925
# [2021-02-22 18:39:38,516]
# 12/20 * Epoch 12 (_base): lr=0.0020 | momentum=0.9000
# 12/20 * Epoch 12 (train): auc=0.5667 | loss=0.6844 | loss_0=0.6849 | loss_1=0.6869 | loss_2=0.6876 | loss_last=0.6824
# 12/20 * Epoch 12 (valid): auc=0.5275 | loss=0.6925 | loss_0=0.6927 | loss_1=0.6920 | loss_2=0.6912 | loss_last=0.6931
# [2021-02-22 18:40:06,374]
# 13/20 * Epoch 13 (_base): lr=0.0020 | momentum=0.9000
# 13/20 * Epoch 13 (train): auc=0.5681 | loss=0.6840 | loss_0=0.6844 | loss_1=0.6868 | loss_2=0.6873 | loss_last=0.6818
# 13/20 * Epoch 13 (valid): auc=0.5277 | loss=0.6922 | loss_0=0.6925 | loss_1=0.6915 | loss_2=0.6915 | loss_last=0.6925
# Early stop at 13 epoch
# Top best models:
# logdir/fold_1/checkpoints/train.2.pth	0.5303
# => Loading checkpoint logdir/fold_1/checkpoints/best_full.pth
# loaded state checkpoint logdir/fold_1/checkpoints/best_full.pth (global epoch 2, epoch 2, stage train)
# [2021-02-22 18:40:55,981]
# 1/20 * Epoch 1 (_base): lr=0.0050 | momentum=0.9000
# 1/20 * Epoch 1 (train): auc=0.5254 | loss=0.6934 | loss_0=0.6925 | loss_1=0.6929 | loss_2=0.6988 | loss_last=0.6920
# 1/20 * Epoch 1 (valid): auc=0.5318 | loss=0.6914 | loss_0=0.6913 | loss_1=0.6915 | loss_2=0.6923 | loss_last=0.6912
# [2021-02-22 18:41:34,397]
# 2/20 * Epoch 2 (_base): lr=0.0050 | momentum=0.9000
# 2/20 * Epoch 2 (train): auc=0.5364 | loss=0.6910 | loss_0=0.6908 | loss_1=0.6913 | loss_2=0.6921 | loss_last=0.6906
# 2/20 * Epoch 2 (valid): auc=0.5303 | loss=0.6916 | loss_0=0.6916 | loss_1=0.6916 | loss_2=0.6916 | loss_last=0.6916
# [2021-02-22 18:42:13,078]
# 3/20 * Epoch 3 (_base): lr=0.0050 | momentum=0.9000
# 3/20 * Epoch 3 (train): auc=0.5404 | loss=0.6903 | loss_0=0.6901 | loss_1=0.6908 | loss_2=0.6913 | loss_last=0.6899
# 3/20 * Epoch 3 (valid): auc=0.5318 | loss=0.6914 | loss_0=0.6916 | loss_1=0.6915 | loss_2=0.6912 | loss_last=0.6914
# [2021-02-22 18:42:51,266]
# 4/20 * Epoch 4 (_base): lr=0.0050 | momentum=0.9000
# 4/20 * Epoch 4 (train): auc=0.5429 | loss=0.6898 | loss_0=0.6896 | loss_1=0.6904 | loss_2=0.6908 | loss_last=0.6893
# 4/20 * Epoch 4 (valid): auc=0.5299 | loss=0.6917 | loss_0=0.6920 | loss_1=0.6918 | loss_2=0.6913 | loss_last=0.6917
# [2021-02-22 18:43:29,467]
# 5/20 * Epoch 5 (_base): lr=0.0050 | momentum=0.9000
# 5/20 * Epoch 5 (train): auc=0.5451 | loss=0.6893 | loss_0=0.6892 | loss_1=0.6901 | loss_2=0.6906 | loss_last=0.6887
# 5/20 * Epoch 5 (valid): auc=0.5301 | loss=0.6917 | loss_0=0.6921 | loss_1=0.6915 | loss_2=0.6915 | loss_last=0.6917
# [2021-02-22 18:44:07,644]
# 6/20 * Epoch 6 (_base): lr=0.0050 | momentum=0.9000
# 6/20 * Epoch 6 (train): auc=0.5471 | loss=0.6889 | loss_0=0.6889 | loss_1=0.6897 | loss_2=0.6903 | loss_last=0.6882
# 6/20 * Epoch 6 (valid): auc=0.5289 | loss=0.6922 | loss_0=0.6926 | loss_1=0.6920 | loss_2=0.6916 | loss_last=0.6924
# [2021-02-22 18:44:45,854]
# 7/20 * Epoch 7 (_base): lr=0.0020 | momentum=0.9000
# 7/20 * Epoch 7 (train): auc=0.5485 | loss=0.6886 | loss_0=0.6887 | loss_1=0.6894 | loss_2=0.6901 | loss_last=0.6878
# 7/20 * Epoch 7 (valid): auc=0.5280 | loss=0.6922 | loss_0=0.6925 | loss_1=0.6922 | loss_2=0.6915 | loss_last=0.6924
# [2021-02-22 18:45:24,313]
# 8/20 * Epoch 8 (_base): lr=0.0020 | momentum=0.9000
# 8/20 * Epoch 8 (train): auc=0.5516 | loss=0.6880 | loss_0=0.6881 | loss_1=0.6890 | loss_2=0.6896 | loss_last=0.6870
# 8/20 * Epoch 8 (valid): auc=0.5289 | loss=0.6925 | loss_0=0.6928 | loss_1=0.6921 | loss_2=0.6918 | loss_last=0.6927
# [2021-02-22 18:46:02,915]
# 9/20 * Epoch 9 (_base): lr=0.0020 | momentum=0.9000
# 9/20 * Epoch 9 (train): auc=0.5536 | loss=0.6876 | loss_0=0.6878 | loss_1=0.6888 | loss_2=0.6893 | loss_last=0.6865
# 9/20 * Epoch 9 (valid): auc=0.5286 | loss=0.6925 | loss_0=0.6928 | loss_1=0.6921 | loss_2=0.6917 | loss_last=0.6927
# [2021-02-22 18:46:41,528]
# 10/20 * Epoch 10 (_base): lr=0.0020 | momentum=0.9000
# 10/20 * Epoch 10 (train): auc=0.5543 | loss=0.6872 | loss_0=0.6876 | loss_1=0.6885 | loss_2=0.6890 | loss_last=0.6861
# 10/20 * Epoch 10 (valid): auc=0.5278 | loss=0.6925 | loss_0=0.6927 | loss_1=0.6922 | loss_2=0.6920 | loss_last=0.6928
# [2021-02-22 18:47:19,794]
# 11/20 * Epoch 11 (_base): lr=0.0020 | momentum=0.9000
# 11/20 * Epoch 11 (train): auc=0.5551 | loss=0.6870 | loss_0=0.6875 | loss_1=0.6883 | loss_2=0.6889 | loss_last=0.6858
# 11/20 * Epoch 11 (valid): auc=0.5303 | loss=0.6926 | loss_0=0.6932 | loss_1=0.6920 | loss_2=0.6918 | loss_last=0.6930
# [2021-02-22 18:47:58,317]
# 12/20 * Epoch 12 (_base): lr=0.0020 | momentum=0.9000
# 12/20 * Epoch 12 (train): auc=0.5559 | loss=0.6868 | loss_0=0.6872 | loss_1=0.6883 | loss_2=0.6887 | loss_last=0.6855
# 12/20 * Epoch 12 (valid): auc=0.5290 | loss=0.6929 | loss_0=0.6933 | loss_1=0.6923 | loss_2=0.6919 | loss_last=0.6934
# [2021-02-22 18:48:36,554]
# 13/20 * Epoch 13 (_base): lr=0.0008 | momentum=0.9000
# 13/20 * Epoch 13 (train): auc=0.5569 | loss=0.6866 | loss_0=0.6873 | loss_1=0.6880 | loss_2=0.6886 | loss_last=0.6853
# 13/20 * Epoch 13 (valid): auc=0.5278 | loss=0.6927 | loss_0=0.6930 | loss_1=0.6922 | loss_2=0.6919 | loss_last=0.6930
# [2021-02-22 18:49:14,682]
# 14/20 * Epoch 14 (_base): lr=0.0008 | momentum=0.9000
# 14/20 * Epoch 14 (train): auc=0.5587 | loss=0.6862 | loss_0=0.6869 | loss_1=0.6878 | loss_2=0.6883 | loss_last=0.6848
# 14/20 * Epoch 14 (valid): auc=0.5286 | loss=0.6928 | loss_0=0.6932 | loss_1=0.6920 | loss_2=0.6919 | loss_last=0.6932
# Early stop at 14 epoch
# Top best models:
# logdir/fold_2/checkpoints/train.3.pth	0.5318
# => Loading checkpoint logdir/fold_2/checkpoints/best_full.pth
# loaded state checkpoint logdir/fold_2/checkpoints/best_full.pth (global epoch 3, epoch 3, stage train)
# [2021-02-22 18:50:15,336]
# 1/20 * Epoch 1 (_base): lr=0.0050 | momentum=0.9000
# 1/20 * Epoch 1 (train): auc=0.5266 | loss=0.6930 | loss_0=0.6923 | loss_1=0.6926 | loss_2=0.6970 | loss_last=0.6919
# 1/20 * Epoch 1 (valid): auc=0.5145 | loss=0.6933 | loss_0=0.6936 | loss_1=0.6933 | loss_2=0.6932 | loss_last=0.6932
# [2021-02-22 18:51:03,992]
# 2/20 * Epoch 2 (_base): lr=0.0050 | momentum=0.9000
# 2/20 * Epoch 2 (train): auc=0.5371 | loss=0.6910 | loss_0=0.6908 | loss_1=0.6913 | loss_2=0.6922 | loss_last=0.6906
# 2/20 * Epoch 2 (valid): auc=0.5160 | loss=0.6935 | loss_0=0.6938 | loss_1=0.6933 | loss_2=0.6931 | loss_last=0.6936
# [2021-02-22 18:51:52,546]
# 3/20 * Epoch 3 (_base): lr=0.0050 | momentum=0.9000
# 3/20 * Epoch 3 (train): auc=0.5387 | loss=0.6906 | loss_0=0.6905 | loss_1=0.6909 | loss_2=0.6914 | loss_last=0.6902
# 3/20 * Epoch 3 (valid): auc=0.5172 | loss=0.6934 | loss_0=0.6934 | loss_1=0.6932 | loss_2=0.6934 | loss_last=0.6935
# [2021-02-22 18:52:41,346]
# 4/20 * Epoch 4 (_base): lr=0.0050 | momentum=0.9000
# 4/20 * Epoch 4 (train): auc=0.5413 | loss=0.6902 | loss_0=0.6901 | loss_1=0.6906 | loss_2=0.6911 | loss_last=0.6897
# 4/20 * Epoch 4 (valid): auc=0.5177 | loss=0.6934 | loss_0=0.6937 | loss_1=0.6929 | loss_2=0.6930 | loss_last=0.6936
# [2021-02-22 18:53:29,781]
# 5/20 * Epoch 5 (_base): lr=0.0050 | momentum=0.9000
# 5/20 * Epoch 5 (train): auc=0.5437 | loss=0.6898 | loss_0=0.6898 | loss_1=0.6904 | loss_2=0.6909 | loss_last=0.6893
# 5/20 * Epoch 5 (valid): auc=0.5176 | loss=0.6939 | loss_0=0.6942 | loss_1=0.6932 | loss_2=0.6933 | loss_last=0.6942
# [2021-02-22 18:54:18,735]
# 6/20 * Epoch 6 (_base): lr=0.0050 | momentum=0.9000
# 6/20 * Epoch 6 (train): auc=0.5447 | loss=0.6895 | loss_0=0.6896 | loss_1=0.6900 | loss_2=0.6906 | loss_last=0.6889
# 6/20 * Epoch 6 (valid): auc=0.5162 | loss=0.6941 | loss_0=0.6939 | loss_1=0.6937 | loss_2=0.6933 | loss_last=0.6945
# [2021-02-22 18:55:07,306]
# 7/20 * Epoch 7 (_base): lr=0.0050 | momentum=0.9000
# 7/20 * Epoch 7 (train): auc=0.5473 | loss=0.6892 | loss_0=0.6893 | loss_1=0.6898 | loss_2=0.6904 | loss_last=0.6885
# 7/20 * Epoch 7 (valid): auc=0.5177 | loss=0.6935 | loss_0=0.6934 | loss_1=0.6933 | loss_2=0.6931 | loss_last=0.6938
# [2021-02-22 18:55:55,751]
# 8/20 * Epoch 8 (_base): lr=0.0050 | momentum=0.9000
# 8/20 * Epoch 8 (train): auc=0.5477 | loss=0.6890 | loss_0=0.6891 | loss_1=0.6897 | loss_2=0.6903 | loss_last=0.6882
# 8/20 * Epoch 8 (valid): auc=0.5179 | loss=0.6941 | loss_0=0.6943 | loss_1=0.6931 | loss_2=0.6933 | loss_last=0.6945
# [2021-02-22 18:56:44,133]
# 9/20 * Epoch 9 (_base): lr=0.0050 | momentum=0.9000
# 9/20 * Epoch 9 (train): auc=0.5494 | loss=0.6887 | loss_0=0.6890 | loss_1=0.6895 | loss_2=0.6901 | loss_last=0.6879
# 9/20 * Epoch 9 (valid): auc=0.5175 | loss=0.6936 | loss_0=0.6938 | loss_1=0.6929 | loss_2=0.6930 | loss_last=0.6940
# [2021-02-22 18:57:32,779]
# 10/20 * Epoch 10 (_base): lr=0.0050 | momentum=0.9000
# 10/20 * Epoch 10 (train): auc=0.5510 | loss=0.6884 | loss_0=0.6887 | loss_1=0.6893 | loss_2=0.6900 | loss_last=0.6874
# 10/20 * Epoch 10 (valid): auc=0.5170 | loss=0.6937 | loss_0=0.6937 | loss_1=0.6932 | loss_2=0.6931 | loss_last=0.6941
# [2021-02-22 18:58:21,547]
# 11/20 * Epoch 11 (_base): lr=0.0050 | momentum=0.9000
# 11/20 * Epoch 11 (train): auc=0.5519 | loss=0.6881 | loss_0=0.6886 | loss_1=0.6890 | loss_2=0.6897 | loss_last=0.6871
# 11/20 * Epoch 11 (valid): auc=0.5185 | loss=0.6932 | loss_0=0.6930 | loss_1=0.6931 | loss_2=0.6928 | loss_last=0.6934
# [2021-02-22 18:59:10,003]
# 12/20 * Epoch 12 (_base): lr=0.0050 | momentum=0.9000
# 12/20 * Epoch 12 (train): auc=0.5529 | loss=0.6878 | loss_0=0.6884 | loss_1=0.6889 | loss_2=0.6896 | loss_last=0.6867
# 12/20 * Epoch 12 (valid): auc=0.5180 | loss=0.6937 | loss_0=0.6938 | loss_1=0.6931 | loss_2=0.6929 | loss_last=0.6942
# [2021-02-22 18:59:58,579]
# 13/20 * Epoch 13 (_base): lr=0.0050 | momentum=0.9000
# 13/20 * Epoch 13 (train): auc=0.5541 | loss=0.6875 | loss_0=0.6881 | loss_1=0.6887 | loss_2=0.6894 | loss_last=0.6862
# 13/20 * Epoch 13 (valid): auc=0.5185 | loss=0.6935 | loss_0=0.6934 | loss_1=0.6930 | loss_2=0.6930 | loss_last=0.6939
# [2021-02-22 19:00:47,454]
# 14/20 * Epoch 14 (_base): lr=0.0050 | momentum=0.9000
# 14/20 * Epoch 14 (train): auc=0.5546 | loss=0.6873 | loss_0=0.6881 | loss_1=0.6885 | loss_2=0.6892 | loss_last=0.6860
# 14/20 * Epoch 14 (valid): auc=0.5193 | loss=0.6933 | loss_0=0.6937 | loss_1=0.6928 | loss_2=0.6927 | loss_last=0.6936
# [2021-02-22 19:01:36,168]
# 15/20 * Epoch 15 (_base): lr=0.0050 | momentum=0.9000
# 15/20 * Epoch 15 (train): auc=0.5556 | loss=0.6871 | loss_0=0.6879 | loss_1=0.6883 | loss_2=0.6892 | loss_last=0.6857
# 15/20 * Epoch 15 (valid): auc=0.5181 | loss=0.6935 | loss_0=0.6938 | loss_1=0.6927 | loss_2=0.6929 | loss_last=0.6938
# [2021-02-22 19:02:24,583]
# 16/20 * Epoch 16 (_base): lr=0.0050 | momentum=0.9000
# 16/20 * Epoch 16 (train): auc=0.5563 | loss=0.6868 | loss_0=0.6876 | loss_1=0.6882 | loss_2=0.6890 | loss_last=0.6854
# 16/20 * Epoch 16 (valid): auc=0.5171 | loss=0.6940 | loss_0=0.6940 | loss_1=0.6930 | loss_2=0.6931 | loss_last=0.6946
# [2021-02-22 19:03:13,433]
# 17/20 * Epoch 17 (_base): lr=0.0050 | momentum=0.9000
# 17/20 * Epoch 17 (train): auc=0.5567 | loss=0.6866 | loss_0=0.6875 | loss_1=0.6880 | loss_2=0.6889 | loss_last=0.6851
# 17/20 * Epoch 17 (valid): auc=0.5190 | loss=0.6940 | loss_0=0.6949 | loss_1=0.6929 | loss_2=0.6927 | loss_last=0.6946
# [2021-02-22 19:04:02,390]
# 18/20 * Epoch 18 (_base): lr=0.0050 | momentum=0.9000
# 18/20 * Epoch 18 (train): auc=0.5572 | loss=0.6865 | loss_0=0.6875 | loss_1=0.6880 | loss_2=0.6887 | loss_last=0.6849
# 18/20 * Epoch 18 (valid): auc=0.5188 | loss=0.6940 | loss_0=0.6941 | loss_1=0.6929 | loss_2=0.6932 | loss_last=0.6946
# [2021-02-22 19:04:52,022]
# 19/20 * Epoch 19 (_base): lr=0.0050 | momentum=0.9000
# 19/20 * Epoch 19 (train): auc=0.5579 | loss=0.6864 | loss_0=0.6874 | loss_1=0.6877 | loss_2=0.6888 | loss_last=0.6848
# 19/20 * Epoch 19 (valid): auc=0.5193 | loss=0.6935 | loss_0=0.6940 | loss_1=0.6927 | loss_2=0.6927 | loss_last=0.6938
# [2021-02-22 19:05:41,000]
# 20/20 * Epoch 20 (_base): lr=0.0050 | momentum=0.9000
# 20/20 * Epoch 20 (train): auc=0.5584 | loss=0.6861 | loss_0=0.6872 | loss_1=0.6876 | loss_2=0.6885 | loss_last=0.6844
# 20/20 * Epoch 20 (valid): auc=0.5200 | loss=0.6933 | loss_0=0.6938 | loss_1=0.6926 | loss_2=0.6927 | loss_last=0.6936
# Top best models:
# logdir/fold_3/checkpoints/train.20.pth	0.5200
# => Loading checkpoint logdir/fold_3/checkpoints/best_full.pth
# loaded state checkpoint logdir/fold_3/checkpoints/best_full.pth (global epoch 20, epoch 20, stage train)
# [2021-02-22 19:06:52,867]
# 1/20 * Epoch 1 (_base): lr=0.0050 | momentum=0.9000
# 1/20 * Epoch 1 (train): auc=0.5243 | loss=0.6930 | loss_0=0.6925 | loss_1=0.6927 | loss_2=0.6963 | loss_last=0.6921
# 1/20 * Epoch 1 (valid): auc=0.5226 | loss=0.6929 | loss_0=0.6931 | loss_1=0.6929 | loss_2=0.6928 | loss_last=0.6929
# [2021-02-22 19:07:52,377]
# 2/20 * Epoch 2 (_base): lr=0.0050 | momentum=0.9000
# 2/20 * Epoch 2 (train): auc=0.5335 | loss=0.6914 | loss_0=0.6913 | loss_1=0.6917 | loss_2=0.6920 | loss_last=0.6911
# 2/20 * Epoch 2 (valid): auc=0.5216 | loss=0.6926 | loss_0=0.6926 | loss_1=0.6927 | loss_2=0.6927 | loss_last=0.6926
# [2021-02-22 19:08:51,299]
# 3/20 * Epoch 3 (_base): lr=0.0050 | momentum=0.9000
# 3/20 * Epoch 3 (train): auc=0.5363 | loss=0.6910 | loss_0=0.6909 | loss_1=0.6913 | loss_2=0.6916 | loss_last=0.6907
# 3/20 * Epoch 3 (valid): auc=0.5207 | loss=0.6928 | loss_0=0.6929 | loss_1=0.6927 | loss_2=0.6927 | loss_last=0.6929
# [2021-02-22 19:09:50,958]
# 4/20 * Epoch 4 (_base): lr=0.0050 | momentum=0.9000
# 4/20 * Epoch 4 (train): auc=0.5381 | loss=0.6907 | loss_0=0.6907 | loss_1=0.6911 | loss_2=0.6914 | loss_last=0.6904
# 4/20 * Epoch 4 (valid): auc=0.5206 | loss=0.6929 | loss_0=0.6931 | loss_1=0.6926 | loss_2=0.6926 | loss_last=0.6930
# [2021-02-22 19:10:49,979]
# 5/20 * Epoch 5 (_base): lr=0.0050 | momentum=0.9000
# 5/20 * Epoch 5 (train): auc=0.5396 | loss=0.6904 | loss_0=0.6904 | loss_1=0.6909 | loss_2=0.6912 | loss_last=0.6900
# 5/20 * Epoch 5 (valid): auc=0.5206 | loss=0.6930 | loss_0=0.6932 | loss_1=0.6928 | loss_2=0.6926 | loss_last=0.6932
# [2021-02-22 19:11:49,149]
# 6/20 * Epoch 6 (_base): lr=0.0050 | momentum=0.9000
# 6/20 * Epoch 6 (train): auc=0.5417 | loss=0.6902 | loss_0=0.6902 | loss_1=0.6908 | loss_2=0.6910 | loss_last=0.6897
# 6/20 * Epoch 6 (valid): auc=0.5206 | loss=0.6931 | loss_0=0.6933 | loss_1=0.6927 | loss_2=0.6927 | loss_last=0.6934
# [2021-02-22 19:12:48,206]
# 7/20 * Epoch 7 (_base): lr=0.0020 | momentum=0.9000
# 7/20 * Epoch 7 (train): auc=0.5424 | loss=0.6900 | loss_0=0.6900 | loss_1=0.6907 | loss_2=0.6908 | loss_last=0.6894
# 7/20 * Epoch 7 (valid): auc=0.5178 | loss=0.6932 | loss_0=0.6934 | loss_1=0.6929 | loss_2=0.6928 | loss_last=0.6933
# [2021-02-22 19:13:47,723]
# 8/20 * Epoch 8 (_base): lr=0.0020 | momentum=0.9000
# 8/20 * Epoch 8 (train): auc=0.5447 | loss=0.6894 | loss_0=0.6896 | loss_1=0.6903 | loss_2=0.6905 | loss_last=0.6888
# 8/20 * Epoch 8 (valid): auc=0.5176 | loss=0.6934 | loss_0=0.6936 | loss_1=0.6929 | loss_2=0.6928 | loss_last=0.6936
# [2021-02-22 19:14:46,475]
# 9/20 * Epoch 9 (_base): lr=0.0020 | momentum=0.9000
# 9/20 * Epoch 9 (train): auc=0.5459 | loss=0.6893 | loss_0=0.6894 | loss_1=0.6902 | loss_2=0.6904 | loss_last=0.6885
# 9/20 * Epoch 9 (valid): auc=0.5183 | loss=0.6932 | loss_0=0.6935 | loss_1=0.6928 | loss_2=0.6927 | loss_last=0.6934
# [2021-02-22 19:15:45,675]
# 10/20 * Epoch 10 (_base): lr=0.0020 | momentum=0.9000
# 10/20 * Epoch 10 (train): auc=0.5467 | loss=0.6891 | loss_0=0.6893 | loss_1=0.6901 | loss_2=0.6903 | loss_last=0.6883
# 10/20 * Epoch 10 (valid): auc=0.5185 | loss=0.6933 | loss_0=0.6935 | loss_1=0.6929 | loss_2=0.6928 | loss_last=0.6936
# [2021-02-22 19:16:45,001]
# 11/20 * Epoch 11 (_base): lr=0.0020 | momentum=0.9000
# 11/20 * Epoch 11 (train): auc=0.5476 | loss=0.6889 | loss_0=0.6892 | loss_1=0.6899 | loss_2=0.6902 | loss_last=0.6881
# 11/20 * Epoch 11 (valid): auc=0.5181 | loss=0.6935 | loss_0=0.6936 | loss_1=0.6931 | loss_2=0.6929 | loss_last=0.6938
# [2021-02-22 19:17:44,354]
# 12/20 * Epoch 12 (_base): lr=0.0020 | momentum=0.9000
# 12/20 * Epoch 12 (train): auc=0.5478 | loss=0.6888 | loss_0=0.6891 | loss_1=0.6899 | loss_2=0.6901 | loss_last=0.6880
# 12/20 * Epoch 12 (valid): auc=0.5191 | loss=0.6934 | loss_0=0.6937 | loss_1=0.6929 | loss_2=0.6928 | loss_last=0.6937
# Early stop at 12 epoch
# Top best models:
# logdir/fold_4/checkpoints/train.1.pth	0.5226
# => Loading checkpoint logdir/fold_4/checkpoints/best_full.pth
# loaded state checkpoint logdir/fold_4/checkpoints/best_full.pth (global epoch 1, epoch 1, stage train)
# [2021-02-22 19:19:07,530]
# 1/20 * Epoch 1 (_base): lr=0.0050 | momentum=0.9000
# 1/20 * Epoch 1 (train): auc=0.5234 | loss=0.6930 | loss_0=0.6925 | loss_1=0.6928 | loss_2=0.6959 | loss_last=0.6922
# 1/20 * Epoch 1 (valid): auc=0.5250 | loss=0.6925 | loss_0=0.6925 | loss_1=0.6926 | loss_2=0.6928 | loss_last=0.6924
# [2021-02-22 19:20:17,311]
# 2/20 * Epoch 2 (_base): lr=0.0050 | momentum=0.9000
# 2/20 * Epoch 2 (train): auc=0.5316 | loss=0.6916 | loss_0=0.6915 | loss_1=0.6918 | loss_2=0.6921 | loss_last=0.6914
# 2/20 * Epoch 2 (valid): auc=0.5274 | loss=0.6921 | loss_0=0.6922 | loss_1=0.6921 | loss_2=0.6923 | loss_last=0.6921
# [2021-02-22 19:21:26,784]
# 3/20 * Epoch 3 (_base): lr=0.0050 | momentum=0.9000
# 3/20 * Epoch 3 (train): auc=0.5337 | loss=0.6913 | loss_0=0.6913 | loss_1=0.6916 | loss_2=0.6918 | loss_last=0.6910
# 3/20 * Epoch 3 (valid): auc=0.5268 | loss=0.6920 | loss_0=0.6921 | loss_1=0.6922 | loss_2=0.6920 | loss_last=0.6920
# [2021-02-22 19:22:36,414]
# 4/20 * Epoch 4 (_base): lr=0.0050 | momentum=0.9000
# 4/20 * Epoch 4 (train): auc=0.5360 | loss=0.6910 | loss_0=0.6910 | loss_1=0.6914 | loss_2=0.6916 | loss_last=0.6907
# 4/20 * Epoch 4 (valid): auc=0.5300 | loss=0.6919 | loss_0=0.6918 | loss_1=0.6919 | loss_2=0.6922 | loss_last=0.6918
# [2021-02-22 19:23:45,852]
# 5/20 * Epoch 5 (_base): lr=0.0050 | momentum=0.9000
# 5/20 * Epoch 5 (train): auc=0.5374 | loss=0.6908 | loss_0=0.6908 | loss_1=0.6913 | loss_2=0.6914 | loss_last=0.6904
# 5/20 * Epoch 5 (valid): auc=0.5288 | loss=0.6919 | loss_0=0.6920 | loss_1=0.6918 | loss_2=0.6919 | loss_last=0.6918
# [2021-02-22 19:24:55,833]
# 6/20 * Epoch 6 (_base): lr=0.0050 | momentum=0.9000
# 6/20 * Epoch 6 (train): auc=0.5391 | loss=0.6906 | loss_0=0.6906 | loss_1=0.6911 | loss_2=0.6913 | loss_last=0.6902
# 6/20 * Epoch 6 (valid): auc=0.5292 | loss=0.6920 | loss_0=0.6920 | loss_1=0.6919 | loss_2=0.6922 | loss_last=0.6920
# [2021-02-22 19:26:05,481]
# 7/20 * Epoch 7 (_base): lr=0.0050 | momentum=0.9000
# 7/20 * Epoch 7 (train): auc=0.5401 | loss=0.6904 | loss_0=0.6905 | loss_1=0.6909 | loss_2=0.6911 | loss_last=0.6899
# 7/20 * Epoch 7 (valid): auc=0.5306 | loss=0.6921 | loss_0=0.6924 | loss_1=0.6918 | loss_2=0.6917 | loss_last=0.6922
# [2021-02-22 19:27:15,374]
# 8/20 * Epoch 8 (_base): lr=0.0050 | momentum=0.9000
# 8/20 * Epoch 8 (train): auc=0.5412 | loss=0.6902 | loss_0=0.6903 | loss_1=0.6908 | loss_2=0.6911 | loss_last=0.6897
# 8/20 * Epoch 8 (valid): auc=0.5318 | loss=0.6919 | loss_0=0.6919 | loss_1=0.6921 | loss_2=0.6918 | loss_last=0.6919
# [2021-02-22 19:28:25,368]
# 9/20 * Epoch 9 (_base): lr=0.0050 | momentum=0.9000
# 9/20 * Epoch 9 (train): auc=0.5420 | loss=0.6900 | loss_0=0.6902 | loss_1=0.6907 | loss_2=0.6909 | loss_last=0.6895
# 9/20 * Epoch 9 (valid): auc=0.5300 | loss=0.6920 | loss_0=0.6921 | loss_1=0.6920 | loss_2=0.6920 | loss_last=0.6920
# [2021-02-22 19:29:35,054]
# 10/20 * Epoch 10 (_base): lr=0.0050 | momentum=0.9000
# 10/20 * Epoch 10 (train): auc=0.5432 | loss=0.6898 | loss_0=0.6900 | loss_1=0.6906 | loss_2=0.6908 | loss_last=0.6892
# 10/20 * Epoch 10 (valid): auc=0.5294 | loss=0.6919 | loss_0=0.6921 | loss_1=0.6920 | loss_2=0.6917 | loss_last=0.6919
# [2021-02-22 19:30:44,372]
# 11/20 * Epoch 11 (_base): lr=0.0050 | momentum=0.9000
# 11/20 * Epoch 11 (train): auc=0.5440 | loss=0.6896 | loss_0=0.6898 | loss_1=0.6905 | loss_2=0.6908 | loss_last=0.6889
# 11/20 * Epoch 11 (valid): auc=0.5295 | loss=0.6921 | loss_0=0.6924 | loss_1=0.6918 | loss_2=0.6920 | loss_last=0.6921
# [2021-02-22 19:31:53,717]
# 12/20 * Epoch 12 (_base): lr=0.0050 | momentum=0.9000
# 12/20 * Epoch 12 (train): auc=0.5447 | loss=0.6894 | loss_0=0.6897 | loss_1=0.6903 | loss_2=0.6906 | loss_last=0.6886
# 12/20 * Epoch 12 (valid): auc=0.5312 | loss=0.6918 | loss_0=0.6920 | loss_1=0.6919 | loss_2=0.6917 | loss_last=0.6918
# [2021-02-22 19:33:03,121]
# 13/20 * Epoch 13 (_base): lr=0.0050 | momentum=0.9000
# 13/20 * Epoch 13 (train): auc=0.5460 | loss=0.6893 | loss_0=0.6896 | loss_1=0.6903 | loss_2=0.6905 | loss_last=0.6884
# 13/20 * Epoch 13 (valid): auc=0.5298 | loss=0.6921 | loss_0=0.6921 | loss_1=0.6921 | loss_2=0.6920 | loss_last=0.6922
# [2021-02-22 19:34:12,379]
# 14/20 * Epoch 14 (_base): lr=0.0020 | momentum=0.9000
# 14/20 * Epoch 14 (train): auc=0.5457 | loss=0.6892 | loss_0=0.6896 | loss_1=0.6902 | loss_2=0.6905 | loss_last=0.6883
# 14/20 * Epoch 14 (valid): auc=0.5293 | loss=0.6921 | loss_0=0.6923 | loss_1=0.6920 | loss_2=0.6917 | loss_last=0.6922
# [2021-02-22 19:35:21,277]
# 15/20 * Epoch 15 (_base): lr=0.0020 | momentum=0.9000
# 15/20 * Epoch 15 (train): auc=0.5477 | loss=0.6887 | loss_0=0.6890 | loss_1=0.6899 | loss_2=0.6903 | loss_last=0.6877
# 15/20 * Epoch 15 (valid): auc=0.5295 | loss=0.6922 | loss_0=0.6924 | loss_1=0.6919 | loss_2=0.6918 | loss_last=0.6923
# [2021-02-22 19:36:31,131]
# 16/20 * Epoch 16 (_base): lr=0.0020 | momentum=0.9000
# 16/20 * Epoch 16 (train): auc=0.5485 | loss=0.6885 | loss_0=0.6890 | loss_1=0.6897 | loss_2=0.6901 | loss_last=0.6875
# 16/20 * Epoch 16 (valid): auc=0.5291 | loss=0.6922 | loss_0=0.6926 | loss_1=0.6919 | loss_2=0.6917 | loss_last=0.6924
# [2021-02-22 19:37:40,980]
# 17/20 * Epoch 17 (_base): lr=0.0020 | momentum=0.9000
# 17/20 * Epoch 17 (train): auc=0.5490 | loss=0.6883 | loss_0=0.6887 | loss_1=0.6897 | loss_2=0.6900 | loss_last=0.6872
# 17/20 * Epoch 17 (valid): auc=0.5298 | loss=0.6923 | loss_0=0.6927 | loss_1=0.6919 | loss_2=0.6919 | loss_last=0.6925
# [2021-02-22 19:38:50,218]
# 18/20 * Epoch 18 (_base): lr=0.0020 | momentum=0.9000
# 18/20 * Epoch 18 (train): auc=0.5498 | loss=0.6883 | loss_0=0.6888 | loss_1=0.6895 | loss_2=0.6900 | loss_last=0.6872
# 18/20 * Epoch 18 (valid): auc=0.5307 | loss=0.6923 | loss_0=0.6926 | loss_1=0.6919 | loss_2=0.6918 | loss_last=0.6924
# [2021-02-22 19:39:59,741]
# 19/20 * Epoch 19 (_base): lr=0.0020 | momentum=0.9000
# 19/20 * Epoch 19 (train): auc=0.5496 | loss=0.6882 | loss_0=0.6887 | loss_1=0.6895 | loss_2=0.6899 | loss_last=0.6870
# 19/20 * Epoch 19 (valid): auc=0.5304 | loss=0.6921 | loss_0=0.6923 | loss_1=0.6920 | loss_2=0.6918 | loss_last=0.6922
# Early stop at 19 epoch
# Top best models:
# logdir/fold_5/checkpoints/train.8.pth	0.5318
# => Loading checkpoint logdir/fold_5/checkpoints/best_full.pth
# loaded state checkpoint logdir/fold_5/checkpoints/best_full.pth (global epoch 8, epoch 8, stage train)

# %%
list(zip(*scores))[1]
# Out:
# (1397.549606904977,
#  1262.8097925495044,
#  1321.7008507083735,
#  1129.4172823292492,
#  1509.1101521204625,
#  1497.360975625355)

# %%
class BlendModel(nn.Module):
    def __init__(self, models, weights):
        super().__init__()
        self.models = nn.ModuleList(models)
        self.weights = weights
    
    def forward(self, x):
        result = 0
        for model, w in zip(self.models, self.weights):
            result += w * model(x)['logits']
        
        return result

# %%
weights = np.array([i**2 for i in range(1, N_SPLITS)])
weights = weights/weights.sum()
weights
# Out:
# array([0.01818182, 0.07272727, 0.16363636, 0.29090909, 0.45454545])

# %%
full_model = BlendModel(models, weights)

# %%
def scoring(dataframe, pred):
    date   = dataframe['date'].values
    weight = dataframe['weight'].values
    resp   = dataframe['resp'].values
    
    best_treshold = None
    best_score    = -1e10
    for treshold in np.linspace(pred.min(), pred.max(), 100):
        score = utility_score_bincount(
            date,
            weight,
            resp,
            np.where(pred >= treshold, 1, 0).astype(int)
        )
        if score > best_score:
            best_treshold = treshold
            best_score    = score
            
    return best_treshold, best_score

def score(model, dataframe):
    loader = get_loaders({'valid':dataframe})['valid']
    
    runner = dl.SupervisedRunner(device='cuda:0', output_key=None)
    predict = runner.predict_loader(
        model  = model,
        loader = loader,
    )
    
    pred = torch.cat([p.sigmoid().cpu() for p in predict])
    pred = pred.numpy().squeeze()
    
    return scoring(dataframe, pred)

# %%
score(full_model, test)
# Out:
# (0.4950006562049942, 1514.1471737043144)

# %%
runner = dl.SupervisedRunner(device='cuda:0', output_key=None)
loaders = get_loaders({'train':data.loc[train_index]})
batch = next(iter(loaders["train"]))

runner.trace(
    model  = full_model,
    batch  = batch, 
    logdir = logdir,
)

model_traced = load_traced_model(
    f"{logdir}/trace/traced-forward.pth", 
    device=device,
)

# %%
score(full_model, data.query('date >= 450').reset_index(drop=True))
# Out:
# (0.527714569460262, 510.82989249216945)

# %%
score(full_model, pd.concat([data.query('date >= 450').reset_index(drop=True), test]).reset_index())
# Out:
# (0.5028380646248056, 1975.5903136660158)
